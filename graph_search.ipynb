# %% [markdown]
# <a href="https://colab.research.google.com/github/dymiyata/advanced-programming-2025-2026/blob/main/graph_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque # A deque is a doubly linked list

class StackFrontier:
  def __init__(self):
    self.data = deque()

  def add(self, item):
    self.data.append(item)

  def remove(self):
    return self.data.pop()

  def is_empty(self):
    return len(self.data) == 0

# %%
def dfs(graph, start, target):
  frontier = StackFrontier()
  frontier.add(start)
  visited = set(start)
  parent = {start: None}

  while not frontier.is_empty():
    node = frontier.remove()
    if node == target:
      print(parent)
      return reconstruct_path(parent, target)
    else:
      neighbors = graph[node]
      for neighbor in neighbors:
        if neighbor not in visited:
          frontier.add(neighbor)
          visited.add(neighbor)
          parent[neighbor] = node

  return False

def reconstruct_path(parent, target):
  current = target
  path = []
  while current:
    path.append(current)
    current = parent[current]
  return path[::-1]

# %%
graph = {
    "A" : ["B", "C"],
    "B" : [],
    "C" : [],
}

# %%
dfs(graph, "A", "B")
# Out:
# {'A': None, 'B': 'A', 'C': 'A'}
# ['A', 'B']
